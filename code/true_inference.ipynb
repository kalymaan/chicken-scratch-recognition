# %%
import helper_functions as hf
from PIL import Image


import tensorflow as tf
from tensorflow import keras
import numpy as np
from tensorflow.keras.layers import StringLookup
import matplotlib.pyplot as plt

# %%
test_image_path = 'data/IAM_Words\words\g06\g06-045d\g06-045d-05-10.png'
string_label = 'Samuel'

# %%
plt.imshow(Image.open(test_image_path), cmap='gray')
plt.title('Corresponding Image')
plt.show();

# %%
test_ds = hf.prepare_dataset([test_image_path], [string_label])
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function process_images_labels at 0x00000220EE524F40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# ...
